# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
model_path=r'models\mf6'
name='sysinoutwel'
wel_coordsin=(0,1,1)
wel_coordsout=(0,8,8)
wel_qin= +0.5
wel_qout= -0.5

# %%
from make_model import make_input
from make_model import run_simulation
from make_model import show_heads
from make_model import show_well_head
from make_model import run_simulation

# %%
make_input(
    wel_qin=wel_qin, 
    wel_qout=wel_qout, 
    wel_coordsin=wel_coordsin, 
    wel_coordsout=wel_coordsout, 
    model_path=model_path, 
    name=name
)

# %%
run_simulation(model_path)

# %%
show_heads(model_path=model_path, name=name)

# %%
show_well_head(model_path=model_path, name=name, wel_coordsin=wel_coordsin, wel_coordsout=wel_coordsout)
