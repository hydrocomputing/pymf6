# %%
model_path=r'models\mf6'
name='sysinoutwel_d100'
wel_coordsin=(0,20,20)
wel_coordsin_1=(0,70,20)
wel_coordsout=(0,20,60)
wel_coordsout_1=(0,70,60)
wel_qin= +0.5
wel_qin_1= +0.7
wel_qout= -0.5
wel_qout_1= -0.7

# %%
from make_model import make_input
from make_model import run_simulation
from make_model import show_heads
from make_model import show_well_head

# %%
make_input(
    wel_qin, 
    wel_qin_1, 
    wel_qout, 
    wel_qout_1, 
    wel_coordsin,
    wel_coordsin_1,
    wel_coordsout,
    wel_coordsout_1,
    model_path,
    name)

# %%
run_simulation(model_path=model_path)

# %%
show_heads(model_path=model_path, name=name)

# %%
show_well_head(model_path=model_path, name=name, wel_coordsin=wel_coordsin, wel_coordsin_1=wel_coordsin_1, wel_coordsout=wel_coordsout, wel_coordsout_1=wel_coordsout_1)
